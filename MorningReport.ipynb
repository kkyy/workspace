# %%
from WindPy import w
import pandas as pd
import numpy as np
import datetime
import calendar
w.start()

today = format(datetime.date.today())
IsWeekend = calendar.weekday(datetime.date.today().year, datetime.date.today().month, datetime.date.today().day) > 4

# %%
SP500 = w.wsd("SPX.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
SP500_Close = SP500[1].iloc[-2,0]
SP500_Change = SP500[1].iloc[-2,1]
SP500_Change_Week = (SP500[1].iloc[-1,0] - SP500[1].iloc[0,0])/SP500[1].iloc[0,0]*100

DJ = w.wsd("DJI.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
DJ_Close = DJ[1].iloc[-2,0]
DJ_Change = DJ[1].iloc[-2,1]
DJ_Change_Week = (DJ[1].iloc[-1,0] - DJ[1].iloc[0,0])/DJ[1].iloc[0,0]*100

NDQ = w.wsd("IXIC.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
NDQ_Close = NDQ[1].iloc[-2,0]
NDQ_Change = NDQ[1].iloc[-2,1]
NDQ_Change_Week = (NDQ[1].iloc[-1,0] - NDQ[1].iloc[0,0])/NDQ[1].iloc[0,0]*100

E50 = w.wsd("SX5E.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
E50_Close = E50[1].iloc[-2,0]
E50_Change = E50[1].iloc[-2,1]
E50_Change_Week = (E50[1].iloc[-1,0] - E50[1].iloc[0,0])/E50[1].iloc[0,0]*100

FTSE = w.wsd("FTSE.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
FTSE_Close = FTSE[1].iloc[-2,0]
FTSE_Change = FTSE[1].iloc[-2,1]

DXI = w.wsd("GDAXI.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
DXI_Close = DXI[1].iloc[-2,0]
DXI_Change = DXI[1].iloc[-2,1]

FCH = w.wsd("FCHI.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
FCH_Close = FCH[1].iloc[-2,0]
FCH_Change = FCH[1].iloc[-2,1]

NIKKI = w.wsd("N225.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
NIKKI_Close = NIKKI[1].iloc[-2,0]
NIKKI_Change = NIKKI[1].iloc[-2,1]
NIKKI_Change_Week = (NIKKI[1].iloc[-1,0] - NIKKI[1].iloc[0,0])/NIKKI[1].iloc[0,0]*100

HSI = w.wsd("HSI.HI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
HSI_Close = HSI[1].iloc[-2,0]
HSI_Change = HSI[1].iloc[-2,1]
HSI_Change_Week = (HSI[1].iloc[-1,0] - HSI[1].iloc[0,0])/HSI[1].iloc[0,0]*100

CSI300 = w.wsd("000300.SH", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
CSI300_Close = CSI300[1].iloc[-2,0]
CSI300_Change = CSI300[1].iloc[-2,1]
CSI300_Change_Week = (CSI300[1].iloc[-1,0] - CSI300[1].iloc[0,0])/CSI300[1].iloc[0,0]*100


XAU = w.wsd("SPTAUUSDOZ.IDC", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
XAU_Close = XAU[1].iloc[-1,0]
XAU_Change = XAU[1].iloc[-1,1]
XAU_Change_Week = (XAU[1].iloc[-1,0] - XAU[1].iloc[0,0])/XAU[1].iloc[0,0]*100

DXY = w.wsd("USDX.FX", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
DXY_Close = DXY[1].iloc[-1,0]
DXY_Change = DXY[1].iloc[-1,1]
DXY_Change_Week = (DXY[1].iloc[-1,0] - DXY[1].iloc[0,0])/DXY[1].iloc[0,0]*100

CNH = w.wsd("USDCNH.FX", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
CNH_Close = CNH[1].iloc[-1,0]
CNH_Change = CNH[1].iloc[-1,1]
CNH_Change_Week = (CNH[1].iloc[-1,0] - CNH[1].iloc[0,0])/CNH[1].iloc[0,0]*100


Bretoil = w.wsd("CL.NYM", "settle", "ED-5TD", today, "TradingCalendar=NYBOT",usedf = True)
Bretoil_Close = Bretoil[1].iloc[-1,0]
Bretoil_Change = (Bretoil[1].iloc[-1] - Bretoil[1].iloc[-2])/Bretoil[1].iloc[-2];Bretoil_Change = Bretoil_Change[0]*100
Bretoil_Change_Week = (Bretoil[1].iloc[-1,0] - Bretoil[1].iloc[0,0])/Bretoil[1].iloc[0,0]*100

WTIoil = w.wsd("CL.NYM", "settle", "ED-5TD", today, "TradingCalendar=NYBOT",usedf = True)
WTIoil_Close = WTIoil[1].iloc[-1,0]
WTIoil_Change = (WTIoil[1].iloc[-1] - WTIoil[1].iloc[-2])/WTIoil[1].iloc[-2];WTIoil_Change = WTIoil_Change[0]*100
WTIoil_Change_Week = (WTIoil[1].iloc[-1,0] - WTIoil[1].iloc[0,0])/WTIoil[1].iloc[0,0]*100

# %%
SP500
# Out:
# (0,
#                CLOSE   PCT_CHG
#  2021-02-10  3909.88 -0.034516
#  2021-02-11  3916.38  0.166246
#  2021-02-12  3934.83  0.471098
#  2021-02-16  3932.59 -0.056927
#  2021-02-17  3931.33 -0.032040
#  2021-02-18  3931.33       NaN)

# %%
if (abs(SP500_Change) < 0.05):
    SP500_F = "标普基本持平，收报"+str(SP500_Close)
else:
    if (SP500_Change>0):
        SP500_F = "标普涨"+str(round(SP500_Change,1))+"%, 收报"+str(SP500_Close)
    else:
        SP500_F = "标普跌"+str(round(SP500_Change*-1,1))+"%, 收报"+str(SP500_Close)

if (abs(DJ_Change) < 0.05):
    DJ_F = "道指基本持平"
else:
    if (DJ_Change>0):
        DJ_F = "道指涨"+str(round(DJ_Change,1))+"%"
    else:
        DJ_F = "道指跌"+str(round(DJ_Change*-1,1))+"%"

if (abs(NDQ_Change) < 0.05):
    NDQ_F = "纳指基本持平"
else:
    if (NDQ_Change>0):
        NDQ_F = "纳指涨"+str(round(NDQ_Change,1))+"%"
    else:
        NDQ_F = "纳指跌"+str(round(NDQ_Change*-1,1))+"%"

SP500_W = "，周涨" + str(round(SP500_Change_Week,1)) + "%" if SP500_Change_Week > 0 else "，周跌" + str(round(SP500_Change_Week*-1,1)) + "%"
DJ_W = "，周涨" + str(round(DJ_Change_Week,1)) + "%" if DJ_Change_Week > 0 else "，周跌" + str(round(DJ_Change_Week*-1,1)) + "%"
NDQ_W = "，周涨" + str(round(NDQ_Change_Week,1)) + "%" if NDQ_Change_Week > 0 else "，周跌" + str(round(NDQ_Change_Week*-1,1)) + "%"

if (abs(NIKKI_Change) < 0.05):
    NIKKI_F = "日经基本持平"
else:
    if (NIKKI_Change>0):
        NIKKI_F = "日经涨"+str(round(NIKKI_Change,1))+"%"
    else:
        NIKKI_F = "日经跌"+str(round(NIKKI_Change*-1,1))+"%"

if (abs(HSI_Change) < 0.05):
    HSI_F = "恒生基本持平"
else:
    if (HSI_Change>0):
        HSI_F = "恒生涨"+str(round(HSI_Change,1))+"%"
    else:
        HSI_F = "恒生跌"+str(round(HSI_Change*-1,1))+"%"

if (abs(CSI300_Change) < 0.05):
    CSI300_F = "沪深300基本持平"
else:
    if (CSI300_Change>0):
        CSI300_F = "沪深300涨"+str(round(CSI300_Change,1))+"%"
    else:
        CSI300_F = "沪深300跌"+str(round(CSI300_Change*-1,1))+"%"

NIKKI_W = "，周涨" + str(round(NIKKI_Change_Week,1)) + "%" if NIKKI_Change_Week > 0 else "，周跌" + str(round(NIKKI_Change_Week*-1,1)) + "%"
HSI_W = "，周涨" + str(round(HSI_Change_Week,1)) + "%" if HSI_Change_Week > 0 else "，周跌" + str(round(HSI_Change_Week*-1,1)) + "%"
CSI300_W = "，周涨" + str(round(CSI300_Change_Week,1)) + "%" if CSI300_Change_Week > 0 else "，周跌" + str(round(CSI300_Change_Week*-1,1)) + "%"

if (abs(E50_Change) < 0.05):
    E50_F = "欧50基本持平"
else:
    if (E50_Change>0):
        E50_F = "欧50涨"+str(round(E50_Change,1))+"%"
    else:
        E50_F = "欧50跌"+str(round(E50_Change*-1,1))+"%"

if (abs(FTSE_Change) < 0.05):
    FTSE_F = "英国基本持平"
else:
    if (FTSE_Change>0):
        FTSE_F = "英国涨"+str(round(FTSE_Change,1))+"%"
    else:
        FTSE_F = "英国跌"+str(round(FTSE_Change*-1,1))+"%"

if (abs(DXI_Change) < 0.05):
    DXI_F = "德国基本持平"
else:
    if (DXI_Change>0):
        DXI_F = "德国涨"+str(round(DXI_Change,1))+"%"
    else:
        DXI_F = "德国跌"+str(round(DXI_Change*-1,1))+"%"
        
if (abs(FCH_Change) < 0.05):
    FCH_F = "法国持平"
else:
    if (FCH_Change>0):
        FCH_F = "法国涨"+str(round(FCH_Change,1))+"%"
    else:
        FCH_F = "法国跌"+str(round(FCH_Change*-1,1))+"%"

E50_W = "，周涨" + str(round(E50_Change_Week,1)) + "%" if E50_Change_Week > 0 else "，周跌" + str(round(E50_Change_Week*-1,1)) + "%"
        
if IsWeekend == False:
    US = SP500_F +"；" + NDQ_F +"；"+ DJ_F + "。"
    Asia = "亚洲方面，" + NIKKI_F +"；" + HSI_F +"；"+ CSI300_F + "。"
else:
    US = SP500_F + SP500_W +"；" + DJ_F + DJ_W +"；"+ NDQ_F + NDQ_W + "。"
    Asia = "亚洲方面，" + NIKKI_F + NIKKI_W +"；" + HSI_F + HSI_W +"；"+ CSI300_F + CSI300_W + "。"
    E50_F = E50_F + E50_W

if (E50_Change>0 and FTSE_Change>0 and DXI_Change>0 and FCH_Change>0):
    EU = "欧股上涨，" + E50_F +"；" + FTSE_F +"；"+ DXI_F + "；" + FCH_F + "。"
elif (E50_Change<0 and FTSE_Change<0 and DXI_Change<0 and FCH_Change<0):
    EU = "欧股下跌，" + E50_F +"；" + FTSE_F +"；"+ DXI_F + "；" + FCH_F + "。"
else:
    EU = "欧股涨跌不一，" + E50_F +"；" + FTSE_F +"；"+ DXI_F + "；" + FCH_F + "。"

if (abs(XAU_Change) < 0.05):
    XAU_F = "金价持平，现货黄金收报"+str(round(XAU_Close,2))
else:
    if (XAU_Change>0):
        XAU_F = "金价上涨，现货黄金收报"+str(round(XAU_Close,2))
    else:
        XAU_F = "金价下跌，现货黄金收报"+str(round(XAU_Close,2))

XAU_W = "，周涨" + str(round(XAU_Change_Week,1)) + "%" if XAU_Change_Week > 0 else "，周跌" + str(round(XAU_Change_Week*-1,1)) + "%"
        
if (abs(DXY_Change) < 0.05):
    DXY_F = "美元持平，DXY收报"+str(round(DXY_Close,2))
else:
    if (DXY_Change>0):
        DXY_F = "美元走高，DXY收报"+str(round(DXY_Close,2))
    else:
        DXY_F = "美元下跌，DXY收报"+str(round(DXY_Close,2))

DXY_W = "，周涨" + str(round(DXY_Change_Week,1)) + "%" if DXY_Change_Week > 0 else "，周跌" + str(round(DXY_Change_Week*-1,1)) + "%"

if (abs(CNH_Change) < 0.05):
    CNH_F = "离岸人民币持平，收报"+str(round(CNH_Close,2))
else:
    if (CNH_Change>0):
        CNH_F = "离岸人民币涨"+str(round(CNH_Change,2))+"%，收报"+str(round(CNH_Close,2))
    else:
        CNH_F = "离岸人民币跌"+str(round(CNH_Change,2))+"%，收报"+str(round(CNH_Close,2))

CNH_W = "，周涨" + str(round(CNH_Change_Week,1)) + "%" if CNH_Change_Week > 0 else "，周跌" + str(round(CNH_Change_Week*-1,1)) + "%"

if (abs(Bretoil_Change) < 0.05):
    Bretoil_F = "布伦特原油期货持平，收报" + str(round(Bretoil_Close,2))
else:
    if (Bretoil_Change>0):
        Bretoil_F = "布伦特原油期货涨"+str(round(Bretoil_Change,2))+"%，收报"+str(round(Bretoil_Close,2))
    else:
        Bretoil_F = "布伦特原油期货跌"+str(round(Bretoil_Change,2))+"%，收报"+str(round(Bretoil_Close,2))

Bretoil_W = "，周涨" + str(round(Bretoil_Change_Week,1)) + "%" if Bretoil_Change_Week > 0 else "，周跌" + str(round(Bretoil_Change_Week*-1,1)) + "%"

if (abs(WTIoil_Change) < 0.05):
    WTIoil_F = "WTI原油期货持平，收报" + str(round(WTIoil_Close,2))
else:
    if (WTIoil_Change>0):
        WTIoil_F = "WTI原油期货涨"+str(round(WTIoil_Change,2))+"%，收报"+str(round(WTIoil_Close,2))
    else:
        WTIoil_F = "WTI原油期货跌"+str(round(WTIoil_Change,2))+"%，收报"+str(round(WTIoil_Close,2))

WTIoil_W = "，周涨" + str(round(WTIoil_Change_Week,1)) + "%" if WTIoil_Change_Week > 0 else "，周跌" + str(round(WTIoil_Change_Week*-1,1)) + "%"

if IsWeekend == True:
    DXY_F = DXY_F + DXY_W
    CNH_F = CNH_F + CNH_W
    XAU_F = XAU_F + XAU_W
    Bretoil_F = Bretoil_F + Bretoil_W
    WTIoil_F = WTIoil_F + WTIoil_W

if (Bretoil_Change>0 and WTIoil_Change>0):
    Oil = '油价上涨，' + Bretoil_F + "；" + WTIoil_F + "。"
elif (Bretoil_Change<0 and WTIoil_Change<0):
    Oil = '油价上涨，' + Bretoil_F + "；" + WTIoil_F + "。"
else:
    Oil = '油价上涨，' + Bretoil_F + "；" + WTIoil_F + "。"

print(US + '\n'+ EU + '\n' + Asia +'\n' + DXY_F +'\n' + CNH_F + "\n" + XAU_F + '\n' + Oil)
# Out:
# 标普基本持平，收报3931.33；道指涨0.3%；纳指跌0.6%。
# 欧股涨跌不一，欧50跌nan%；英国跌0.6%；德国跌nan%；法国跌0.4%。
# 亚洲方面，日经跌0.6%；恒生涨1.1%；沪深300跌nan%。
# 美元下跌，DXY收报90.6
# 离岸人民币跌nan%，收报6.43
# 金价下跌，现货黄金收报1794.34
# 油价上涨，布伦特原油期货持平，收报60.05；WTI原油期货持平，收报60.05。

# %%
E50
# Out:
# (0,
#                CLOSE   PCT_CHG
#  2021-02-10  3648.37 -0.348526
#  2021-02-11  3671.68  0.638915
#  2021-02-12  3695.61  0.651745
#  2021-02-16  3726.40 -0.208880
#  2021-02-17  3726.40       NaN
#  2021-02-18  3726.40       NaN)

# %%
#周末
SP500 = w.wsd("SPX.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
SP500_Close = SP500[1].iloc[-1,0]
SP500_Change = SP500[1].iloc[-1,1]
SP500_Change_Week = (SP500[1].iloc[-1,0] - SP500[1].iloc[0,0])/SP500[1].iloc[0,0]*100

DJ = w.wsd("DJI.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
DJ_Close = DJ[1].iloc[-1,0]
DJ_Change = DJ[1].iloc[-1,1]
DJ_Change_Week = (DJ[1].iloc[-1,0] - DJ[1].iloc[0,0])/DJ[1].iloc[0,0]*100

NDQ = w.wsd("IXIC.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
NDQ_Close = NDQ[1].iloc[-1,0]
NDQ_Change = NDQ[1].iloc[-1,1]
NDQ_Change_Week = (NDQ[1].iloc[-1,0] - NDQ[1].iloc[0,0])/NDQ[1].iloc[0,0]*100

E50 = w.wsd("SX5E.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
E50_Close = E50[1].iloc[-1,0]
E50_Change = E50[1].iloc[-1,1]
E50_Change_Week = (E50[1].iloc[-1,0] - E50[1].iloc[0,0])/E50[1].iloc[0,0]*100

FTSE = w.wsd("FTSE.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
FTSE_Close = FTSE[1].iloc[-1,0]
FTSE_Change = FTSE[1].iloc[-1,1]

DXI = w.wsd("GDAXI.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
DXI_Close = DXI[1].iloc[-1,0]
DXI_Change = DXI[1].iloc[-1,1]

FCH = w.wsd("FCHI.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
FCH_Close = FCH[1].iloc[-1,0]
FCH_Change = FCH[1].iloc[-1,1]

NIKKI = w.wsd("N225.GI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
NIKKI_Close = NIKKI[1].iloc[-1,0]
NIKKI_Change = NIKKI[1].iloc[-1,1]
NIKKI_Change_Week = (NIKKI[1].iloc[-1,0] - NIKKI[1].iloc[0,0])/NIKKI[1].iloc[0,0]*100

HSI = w.wsd("HSI.HI", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
HSI_Close = HSI[1].iloc[-1,0]
HSI_Change = HSI[1].iloc[-1,1]
HSI_Change_Week = (HSI[1].iloc[-1,0] - HSI[1].iloc[0,0])/HSI[1].iloc[0,0]*100

CSI300 = w.wsd("000300.SH", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
CSI300_Close = CSI300[1].iloc[-1,0]
CSI300_Change = CSI300[1].iloc[-1,1]
CSI300_Change_Week = (CSI300[1].iloc[-1,0] - CSI300[1].iloc[0,0])/CSI300[1].iloc[0,0]*100


XAU = w.wsd("SPTAUUSDOZ.IDC", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
XAU_Close = XAU[1].iloc[-1,0]
XAU_Change = XAU[1].iloc[-1,1]
XAU_Change_Week = (XAU[1].iloc[-1,0] - XAU[1].iloc[0,0])/XAU[1].iloc[0,0]*100

DXY = w.wsd("USDX.FX", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
DXY_Close = DXY[1].iloc[-1,0]
DXY_Change = DXY[1].iloc[-1,1]
DXY_Change_Week = (DXY[1].iloc[-1,0] - DXY[1].iloc[0,0])/DXY[1].iloc[0,0]*100

CNH = w.wsd("USDCNH.FX", "close,pct_chg", "ED-5TD", today, "TradingCalendar=NYSE",usedf = True)
CNH_Close = CNH[1].iloc[-1,0]
CNH_Change = CNH[1].iloc[-1,1]
CNH_Change_Week = (CNH[1].iloc[-1,0] - CNH[1].iloc[0,0])/CNH[1].iloc[0,0]*100

Bretoil = w.wsd("CL.NYM", "settle", "ED-5TD", today, "TradingCalendar=NYBOT",usedf = True)
Bretoil_Close = Bretoil[1].iloc[-1,0]
Bretoil_Change = (Bretoil[1].iloc[-1] - Bretoil[1].iloc[-2])/Bretoil[1].iloc[-2];Bretoil_Change = Bretoil_Change[0]*100
Bretoil_Change_Week = (Bretoil[1].iloc[-1,0] - Bretoil[1].iloc[0,0])/Bretoil[1].iloc[0,0]*100

WTIoil = w.wsd("CL.NYM", "settle", "ED-5TD", today, "TradingCalendar=NYBOT",usedf = True)
WTIoil_Close = WTIoil[1].iloc[-1,0]
WTIoil_Change = (WTIoil[1].iloc[-1] - WTIoil[1].iloc[-2])/WTIoil[1].iloc[-2];WTIoil_Change = WTIoil_Change[0]*100
WTIoil_Change_Week = (WTIoil[1].iloc[-1,0] - WTIoil[1].iloc[0,0])/WTIoil[1].iloc[0,0]*100
